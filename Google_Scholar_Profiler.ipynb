# %% [markdown]
# <a href="https://colab.research.google.com/github/Soul-Jacker/GoogleScholarProfiler/blob/main/Google_Scholar_Profiler.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Google Scholar Profiler
#
# ---
#
# This notebook serves as an interface to facilitate the collection of Google Scholar profile data.  The current implementation uses the  `scholarly` module.  Currently, this notebook returns a limited amount of data from each profile.  Users do not need to know how to program in Python to use this notebook.  Simply read each section of the notebook and run each set of command.  The code is hidden from the user, but each section can be expanded (or unhidden) to examine the underlying code.
#
# Searches can be done using either a scholar's name or their Google Scholar ID.  Please note the following:
#
# *   This notebook can only extract Google Scholar profile data *if* a profile exists.  Users will have to use other software like _Publish or Perish_ if they want to examine metrics for scholars without a Google Scholar profile.
# *   The ideal method for extracting profile data is from a Scholar ID rather than a name.  Since Google Scholar covers all the scientific disciplines, there are numerous scholars with the same name.
#
# To find a Google Scholar ID, the user can perform a quick search with this notebook, which may return the ID (assuming the search was successful).  Otherwise, you can obtain a Google ID from a scholar's profile in the URL of their actual profile page.  The following example shows where in the URL the ID is embedded.

# %% [markdown]
# #### Workspace set-up
# This section installs the `scholarly` and `pandas` in quiet mode.  Feel free to expand this section to examine the code block.  Note that users have to run this only a single time in a given session.

# %%
# !pip install --upgrade gspread -q

# %%
# !pip install scholarly==0.2.1
# Out:
# Collecting scholarly==0.2.1
#   Downloading scholarly-0.2.1-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: requests[security] in /usr/local/lib/python3.7/dist-packages (from scholarly==0.2.1) (2.23.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from scholarly==0.2.1) (4.6.3)
# Collecting bibtexparser
#   Downloading bibtexparser-1.2.0.tar.gz (46 kB)
#      |████████████████████████████████| 46 kB 2.2 MB/s
# Collecting arrow
#   Downloading arrow-1.2.2-py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 1.9 MB/s
# Requirement already satisfied: python-dateutil>=2.7.0 in /usr/local/lib/python3.7/dist-packages (from arrow->scholarly==0.2.1) (2.8.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from arrow->scholarly==0.2.1) (4.1.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.0->arrow->scholarly==0.2.1) (1.15.0)
# Requirement already satisfied: pyparsing>=2.0.3 in /usr/local/lib/python3.7/dist-packages (from bibtexparser->scholarly==0.2.1) (3.0.8)
# Requirement already satisfied: future>=0.16.0 in /usr/local/lib/python3.7/dist-packages (from bibtexparser->scholarly==0.2.1) (0.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[security]->scholarly==0.2.1) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[security]->scholarly==0.2.1) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[security]->scholarly==0.2.1) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[security]->scholarly==0.2.1) (2.10)
# Collecting cryptography>=1.3.4
#   Downloading cryptography-36.0.2-cp36-abi3-manylinux_2_24_x86_64.whl (3.6 MB)
#      |████████████████████████████████| 3.6 MB 45.7 MB/s
# Collecting pyOpenSSL>=0.14
#   Downloading pyOpenSSL-22.0.0-py2.py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 3.6 MB/s
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.7/dist-packages (from cryptography>=1.3.4->requests[security]->scholarly==0.2.1) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.12->cryptography>=1.3.4->requests[security]->scholarly==0.2.1) (2.21)
# Building wheels for collected packages: bibtexparser
#   Building wheel for bibtexparser (setup.py) ... done
#   Created wheel for bibtexparser: filename=bibtexparser-1.2.0-py3-none-any.whl size=36713 sha256=a2abe542155e2808a8bb6be8f38e6d47a9f788993e90df5cb1389dce0337cf97
#   Stored in directory: /root/.cache/pip/wheels/3e/13/1d/09c37a40f39ddd7b226719a797f1896a5b95d730de27e7a505
# Successfully built bibtexparser
# Installing collected packages: cryptography, pyOpenSSL, bibtexparser, arrow, scholarly
# Successfully installed arrow-1.2.2 bibtexparser-1.2.0 cryptography-36.0.2 pyOpenSSL-22.0.0 scholarly-0.2.1

# %%
from scholarly import scholarly
import pandas as pd
from google.colab import auth
import gspread
from oauth2client.client import GoogleCredentials
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-7249bc0098f4> in <module>()
# ----> 1 from scholarly import scholarly
#       2 import pandas as pd
#       3 from google.colab import auth
#       4 import gspread
#       5 from oauth2client.client import GoogleCredentials
#
# ImportError: cannot import name 'scholarly' from 'scholarly' (/usr/local/lib/python3.7/dist-packages/scholarly.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# ## Quick search for a single author
# ---
#
# Run this code block to perform a search for a given author, either by the scholar's name.  This can be a quick way to examine a profile and obtain the `scholar_id` in the output.  Please enter the scholar's name directly without any quotes.

# %%
#@title Run the single author search { form-width: "25%", display-mode: "form" }


Scholar_Name = "Robert Joseph Taylor" #@param {type:"string"}

#search_query = scholarly.search_author('Brian Perron')
search_query = scholarly.search_pubs_query('The perception of physical stability of 3d objects The role of parts')

author = next(search_query)
#scholarly.pprint(scholarly.fill(author, sections=['basics', 'indices']))
single_df = scholarly.fill(author, sections=['basics', 'indices'])
#single_df.pop('interests')
single_out = pd.DataFrame(single_df.items())
single_out = single_out.set_index(0).T
single_out = single_out.drop(['container_type', 'filled', 'source', 'url_picture', 'interests'], axis = 1)
single_out = single_out[['name', 'scholar_id', 'affiliation', 'email_domain', 'citedby', 'citedby5y', 'hindex', 'hindex5y', 'i10index', 'i10index5y']]
del(single_df)
single_out = single_out.T
print(single_out)

# %% [markdown]
# ## Multiple author search
#
# In this code block, the user can perform a search from a list of names from a Google Sheet found [here](https://docs.google.com/spreadsheets/d/13oHxzWswrzJkWUJRHx7Ljwlq50MGWRTlwWwoEDKcgcs/edit?usp=sharing).  Please note this is a public sheet for demonstration purposes.  Please note that the user will be prompted to authenticate.  You will be provided a link and then you can copy and paste the access code to perform the search.

# %%
#@title Run multiple author search {display-mode: "form"}
# %load_ext google.colab.data_table

auth.authenticate_user()
gc = gspread.authorize(GoogleCredentials.get_application_default())

worksheet = gc.open('GoogleScholarProfiler_INPUT').sheet1

# get_all_values gives a list of rows.
rows = worksheet.get_all_values()
#print(rows)

#Convert to a DataFrame and render.

a = pd.DataFrame.from_records(rows)
my_authors = a[0]
#df1 = single_out.drop(df.index, inplace = True)

df = scholarly.fill(author, sections=['basics', 'indices'])
df1 = pd.DataFrame(df.items())


#my_authors = ["Katie Richards-Schuster", "Lisa Wexler", "Todd Herrenkohl", "Lorraine Gutierrez", "Robert Joseph Taylor"]

for who in my_authors:
  try:
    print('retrieving:     ', who)
    search_query = scholarly.search_author(who)
    author = next(search_query)
    hope = scholarly.fill(author, sections=['basics', 'indices'])
    df = pd.DataFrame(hope.items())
    df = df.set_index(0).T
    df1 = pd.concat([df1, df])
  except:
    print('COULD NOT FIND: ', who)
    continue

df1 = df1.reset_index(drop = True)
df1 = df1.drop_duplicates(subset=['scholar_id'])
df1.drop([0,1], axis=1, inplace=True)
df1.drop([0], axis=0, inplace = True)
df1.drop(['container_type', 'filled', 'source', 'url_picture'], axis = 1)
df1 = df1[['name', 'scholar_id', 'affiliation', 'email_domain', 'citedby', 'citedby5y', 'hindex', 'hindex5y', 'i10index', 'i10index5y', 'interests']]
df1 = df1.reset_index(drop = True)
df1
# Out:
# retrieving:      Cristina Bares
# retrieving:      William Elliott
# retrieving:      Terri Friedline
# retrieving:      Shawna Lee
# retrieving:      Kathryn Maguire-Jack
# retrieving:      Sandra Momper
# COULD NOT FIND:  Sandra Momper
# retrieving:      Emily Nicklett
# retrieving:      Brian Perron
# retrieving:      Rogerio Pinto
# retrieving:      Luke Shaefer
# retrieving:      Trina Williams Shanks
# COULD NOT FIND:  Trina Williams Shanks
# retrieving:      Daphne Watkins
# retrieving:      Derek Brown
# retrieving:      Sheretta Butler-Barnes
# retrieving:      Leopoldo Cabassa
# retrieving:      Alexis Duncan
# retrieving:      Amy Eyler
# retrieving:      Patrick Fowler
# retrieving:      Michal Grinstein-Weiss
# retrieving:      Jenine Harris
# retrieving:      David Patterson Silver Wolf
# retrieving:      Carmela Alc√°ntara
# COULD NOT FIND:  Carmela Alc√°ntara
# retrieving:      Heidi Allen
# retrieving:      Jinyu Liu
# retrieving:      Desmond Patton
# retrieving:      Craig Schwalbe
# retrieving:      Elwin Wu
# retrieving:      Gina Chowa
# retrieving:      Gary Cuddeback
# COULD NOT FIND:  Gary Cuddeback
# retrieving:      Trenette Clark Goings
# retrieving:      Paul Lanier
# retrieving:      Melissa Lippold
# retrieving:      Amelia Gavin
# COULD NOT FIND:  Amelia Gavin
# retrieving:      Ruben Parra-Cardona
# retrieving:      Kirk Von Sternberg
# retrieving:      Mark Joseph
# retrieving:      Megan Holmes
# retrieving:      Nancy Rolock
# retrieving:      Jessica Black
# retrieving:      Roc√≠o Calvo
# COULD NOT FIND:  Roc√≠o Calvo
# retrieving:      Thomas Crea
# retrieving:      Scott Easton
# retrieving:      Summer Sherburne Hawkins
# retrieving:      Margaret Lombe
# retrieving:      Christina Matz
# retrieving:      Allison Werner-Lin
# retrieving:      Hyeouk Chris Hahm
# retrieving:      Daniel Miller
# retrieving:      Jordana Muroff
# COULD NOT FIND:  Jordana Muroff
# retrieving:      Ruth Paris
# retrieving:      Christopher Salas-Wright
# retrieving:      Linda Sprague Martinez
# retrieving:      Ezekiel Dixon-Rom√°n
# COULD NOT FIND:  Ezekiel Dixon-Rom√°n
# retrieving:      Toorjo Ghose
# COULD NOT FIND:  Toorjo Ghose
# retrieving:      Johanna Greeson
# retrieving:      Darcey Merritt
# retrieving:      Victoria Stanhope
# retrieving:      Jennifer Manuel
# retrieving:      Alicia Bunger
# retrieving:      Michelle Johnson-Motoyama
# retrieving:      Michelle Kaiser
# retrieving:      Sharvari Karandikar
# retrieving:      Renee Olate
# retrieving:      Ian Holloway
# retrieving:      Tally Moses
# COULD NOT FIND:  Tally Moses
# retrieving:      Edward Alessi
# retrieving:      DuWayne Battle
# COULD NOT FIND:  DuWayne Battle
# retrieving:      Patricia Findley
# retrieving:      Emily Greenfield
# retrieving:      Myungkook Joo
# COULD NOT FIND:  Myungkook Joo
# retrieving:      Jeounghee Kim
# retrieving:      Judith McCoyd
# retrieving:      Sarah McMahon
# COULD NOT FIND:  Sarah McMahon
# retrieving:      Lenna Nepomnyaschy
# retrieving:      Karen Zurlo
# retrieving:      Haksoon Ahn
# COULD NOT FIND:  Haksoon Ahn
# retrieving:      Melissa Bellin
# COULD NOT FIND:  Melissa Bellin
# retrieving:      Charlotte Lyn Bright
# COULD NOT FIND:  Charlotte Lyn Bright
# retrieving:      Joan Davitt
# COULD NOT FIND:  Joan Davitt
# retrieving:      Nadine Finigan-Carr
# retrieving:      Jodi Jacobson Frey
# COULD NOT FIND:  Jodi Jacobson Frey
# retrieving:      Elizabeth Greeno
# COULD NOT FIND:  Elizabeth Greeno
# retrieving:      Amanda Lehning
# retrieving:      Bethany Lee
# retrieving:      Nalini Negi
# retrieving:      Paul Sacco
# retrieving:      Terry Shaw
# retrieving:      Michael Woolley
# retrieving:      Sarah Goodkind
# COULD NOT FIND:  Sarah Goodkind
# retrieving:      Jeffrey Shook
# COULD NOT FIND:  Jeffrey Shook
# retrieving:      Vincent Guilamo-Ramos
# retrieving:      Wen-jui Han
# retrieving:      Michael Lindsey
# retrieving:      Michelle Munson
# retrieving:      Ramesh Raghavan
# retrieving:      Qingwen Xu
# retrieving:      Dawn Anderson-Butcher
# COULD NOT FIND:  Dawn Anderson-Butcher
# retrieving:      Bridget Freisthler
# retrieving:      Natasha Bowen
# retrieving:      Ramona Denby-Brinson
# COULD NOT FIND:  Ramona Denby-Brinson
# retrieving:      Laura Abrams
# retrieving:      Lawrence Berger
# retrieving:      Marah Curtis
# retrieving:      Katherine Magnuson
# retrieving:      Tracy Schroepfer
# retrieving:      Kristen Slack
# retrieving:      Antoinette Farmer
# retrieving:      Chien-Chung Huang
# retrieving:      Andrew Peterson
# retrieving:      Judy Postmus
# retrieving:      Corey Shdaimah
# COULD NOT FIND:  Corey Shdaimah
# retrieving:      Valire Carr Copeland
# COULD NOT FIND:  Valire Carr Copeland
# retrieving:      Shaun Eack
# retrieving:      Daniel Rosen
# retrieving:      Christina Newhill
# retrieving:      Fengyan Tang
# COULD NOT FIND:  Fengyan Tang
# retrieving:      John Wallace
# retrieving:      Andrew Grogan-Kaylor
# retrieving:      Todd Herrenkohl
# retrieving:      Joseph Himle
# retrieving:      Lydia Li
# retrieving:      Mary Ruffolo
# retrieving:      Mieko Yoshihama
# COULD NOT FIND:  Mieko Yoshihama
# retrieving:      Bradley Zebrack
# retrieving:      Melissa Jonson-Reed
# COULD NOT FIND:  Melissa Jonson-Reed
# retrieving:      Carolyn Lesorogol
# retrieving:      Fred Ssewamala
# COULD NOT FIND:  Fred Ssewamala
# retrieving:      Craig Scwalbe
# retrieving:      Julien Teitler
# retrieving:      Susan Witte
# retrieving:      Mimi Chapman
# retrieving:      Rebecca Macy
# retrieving:      Bonnie Duran
# retrieving:      Elena Erosheva
# retrieving:      Karen Fredriksen-Goldsen
# retrieving:      Michael Spencer
# retrieving:      Karina Walters
# retrieving:      Renee Spencer
# retrieving:      Ellen DeVoe
# COULD NOT FIND:  Ellen DeVoe
# retrieving:      Mary Elizabeth Collins
# retrieving:      Jacqueline Corcoran
# retrieving:      Zvi Gellis
# retrieving:      No√´l Busch-Armendariz
# COULD NOT FIND:  No√´l Busch-Armendariz
# retrieving:      Lori Holleran Steiker
# retrieving:      Barbara Jones
# retrieving:      Sandra Maga√±a
# COULD NOT FIND:  Sandra Maga√±a
# retrieving:      Aloen Townsend
# COULD NOT FIND:  Aloen Townsend
# retrieving:      Shanta Pandey
# COULD NOT FIND:  Shanta Pandey
#                          name  ...                                          interests
# 0              Cristina Bares  ...  [adolescent substance use, mental health, ciga...
# 1               Keith Crocker  ...                                                 []
# 2             Terri Friedline  ...                              [Financial inclusion]
# 3               Shawna J. Lee  ...  [fathering, child welfare, parenting programs,...
# 4        Kathryn Maguire-Jack  ...    [Child maltreatment, prevention, neighborhoods]
# ..                        ...  ...                                                ...
# 108    Mary Elizabeth Collins  ...  [child welfare, aging out of care, youth servi...
# 109       Jacqueline Corcoran  ...                                                 []
# 110                Zvi Gellis  ...  [Social Work, Geriatrics, Mental Health, Geron...
# 111  Lori K. Holleran Steiker  ...  [Youth and Substance Misuse, use disorders and...
# 112          Barbara E. Jones  ...                                     [Neuroscience]
#
# [113 rows x 11 columns]

# %% [markdown]
# ### Write the results to a Google Sheet

# %%
dfCombined = df1.copy()

# %%
dfCombined = dfCombined.drop(['interests'], axis=1)

# %%
lOfLists = dfCombined.to_numpy().tolist()
headers = dfCombined.columns.to_list()
dataToWrite = [headers] + lOfLists
worksheet = gc.open('GoogleScholarProfiler_OUTPUT').sheet1
worksheet.update(None, dataToWrite)
# Out:
# {'spreadsheetId': '12oCjjSktXXs7X3v6WZyGmWB8BW-q04thCqANiGCC4nU',
#  'updatedCells': 1140,
#  'updatedColumns': 10,
#  'updatedRange': 'Sheet1!A1:J114',
#  'updatedRows': 114}
